# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
n_points = 11
t = np.linspace(0,2,n_points)
print('tiempos=',t)
# Out:
# tiempos= [ 0.   0.2  0.4  0.6  0.8  1.   1.2  1.4  1.6  1.8  2. ]

# %%
x = 6 * t
print('x=', x)
# Out:
# x= [  0.    1.2   2.4   3.6   4.8   6.    7.2   8.4   9.6  10.8  12. ]

# %%
y = -t*t/2 + t
print('y=', y)
# Out:
# y= [ 0.    0.18  0.32  0.42  0.48  0.5   0.48  0.42  0.32  0.18  0.  ]

# %%
plt.plot(t,x)
plt.xlabel("t")
plt.ylabel("x")

# %%
plt.plot(t,y)
plt.xlabel("t")
plt.ylabel("y")

# %%
plt.plot(x,y)
plt.xlabel("x")
plt.ylabel("y")
